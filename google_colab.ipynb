# %%
! git clone https://github.com/corazon008/emospeech.git
! pip install uv

# %%
import sys
sys.path.append('emospeech')

# %% [markdown]
# # Move into repo

# %%
# %cd emospeech

# %%
! uv sync

# %% [markdown]
# # Download data

# %%
! uv run download_data.py

# %% [markdown]
# # Preprocess

# %%
! uv run -m src.preprocess.preprocess

# %% [markdown]
# # Training

# %%
! uv run -m src.scripts.test
